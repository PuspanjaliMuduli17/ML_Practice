# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image,display_svg,SVG

# %%
from sklearn.datasets import load_iris
df=load_iris()
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()

# %%
X=df.data
y=df.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import  plot_tree

# %%
plot_tree(clf)
# Out:
# [Text(0.4, 0.9, 'x[2] <= 2.35\ngini = 0.665\nsamples = 120\nvalue = [36, 42, 42]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(0.5, 0.7, 'x[3] <= 1.65\ngini = 0.5\nsamples = 84\nvalue = [0, 42, 42]'),
#  Text(0.2, 0.5, 'x[2] <= 4.95\ngini = 0.127\nsamples = 44\nvalue = [0, 41, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.3, 0.3, 'x[3] <= 1.55\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'x[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.7, 0.3, 'x[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]')]

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in /Users/puja/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (2.1.4)
# Requirement already satisfied: numpy in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (1.4.2)
# Requirement already satisfied: matplotlib in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (3.8.0)
# Requirement already satisfied: colour in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in /Users/puja/anaconda3/lib/python3.11/site-packages (from dtreeviz) (7.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/puja/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas->dtreeviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in /Users/puja/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/puja/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
conda install -c conda-forge dtreeviz
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
