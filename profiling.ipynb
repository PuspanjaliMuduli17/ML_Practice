# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# !pip install pandas profiling
# Out:
# Requirement already satisfied: pandas in /Users/puja/anaconda3/lib/python3.11/site-packages (2.2.1)
# Collecting profiling
#   Downloading profiling-0.1.3.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/puja/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Collecting valuedispatch>=0.0.1 (from profiling)
#   Downloading valuedispatch-0.0.1.tar.gz (1.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=4.1 in /Users/puja/anaconda3/lib/python3.11/site-packages (from profiling) (8.1.7)
# Collecting click-default-group>=1.2 (from profiling)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.8.0 in /Users/puja/anaconda3/lib/python3.11/site-packages (from profiling) (1.16.0)
# Collecting urwid>=1.2.1 (from profiling)
#   Downloading urwid-2.6.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions in /Users/puja/anaconda3/lib/python3.11/site-packages (from urwid>=1.2.1->profiling) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/puja/anaconda3/lib/python3.11/site-packages (from urwid>=1.2.1->profiling) (0.2.5)
# Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Downloading urwid-2.6.8-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.4/295.4 kB 1.7 MB/s eta 0:00:00a 0:00:01m
# Building wheels for collected packages: profiling, valuedispatch
#   Building wheel for profiling (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [52 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-311
#       creating build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/viewer.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/utils.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/stats.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/sortkeys.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/__about__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/profiler.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       copying profiling/__main__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling
#       creating build/lib.macosx-11.1-arm64-cpython-311/profiling/tracing
#       copying profiling/tracing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/tracing
#       copying profiling/tracing/timers.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/tracing
#       creating build/lib.macosx-11.1-arm64-cpython-311/profiling/sampling
#       copying profiling/sampling/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/sampling
#       copying profiling/sampling/samplers.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/sampling
#       creating build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/gevent.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/client.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/asyncio.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/background.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       copying profiling/remote/select.py -> build/lib.macosx-11.1-arm64-cpython-311/profiling/remote
#       running build_ext
#       building 'profiling.speedup' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311
#       creating build/temp.macosx-11.1-arm64-cpython-311/profiling
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/puja/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/puja/anaconda3/include -arch arm64 -I/Users/puja/anaconda3/include/python3.11 -c profiling/speedup.c -o build/temp.macosx-11.1-arm64-cpython-311/profiling/speedup.o
#       profiling/speedup.c:28:41: error: incomplete definition of type 'struct _frame'
#               if (frame == base_frame || frame->f_code == base_code)
#                                          ~~~~~^
#       /Users/puja/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of 'struct _frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       profiling/speedup.c:33:62: error: incomplete definition of type 'struct _frame'
#                   PySet_Contains((PYOBJ)ignored_codes, (PYOBJ)frame->f_code) == 0)
#                                                               ~~~~~^
#       /Users/puja/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of 'struct _frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       profiling/speedup.c:41:22: error: incomplete definition of type 'struct _frame'
#               frame = frame->f_back;
#                       ~~~~~^
#       /Users/puja/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of 'struct _frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       3 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for profiling
#   Running setup.py clean for profiling
#   Building wheel for valuedispatch (setup.py) ... done
#   Created wheel for valuedispatch: filename=valuedispatch-0.0.1-py3-none-any.whl size=2021 sha256=a5cd0da15c6af880102df9a99f160469c230a27f556dcb1616649d675b40f81e
#   Stored in directory: /Users/puja/Library/Caches/pip/wheels/b1/c8/5a/eeddf7d7b715b54f0ff4cd7d8626fa24f2b01561c294b68aeb
# Successfully built valuedispatch
# Failed to build profiling
# ERROR: Could not build wheels for profiling, which is required to install pyproject.toml-based projects

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# /var/folders/xy/sskkgn4s2rngs918k4r4hs4h0000gn/T/ipykernel_34839/867096850.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/puja/anaconda3/lib/python3.11/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'S'')
#   warnings.warn(
# /Users/puja/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /Users/puja/anaconda3/lib/python3.11/site-packages/ydata_profiling/model/missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '--'')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
