# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('tips.csv')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2=pd.read_csv('train.csv')

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3=pd.read_csv('iris.csv')

# %%
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df4=pd.read_csv('flights.csv')

# %%
df4
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.scatterplot(data=df1,x=df1['total_bill'],y=df1['tip'],hue=df1['sex'],style=df1['smoker'],size=df1['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x=df2['Pclass'],y=df2['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df2['Pclass'],y=df2['Fare'],hue=df2['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x=df2['Sex'],y=df2['Age'],hue=df2['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(df2[df2['Survived']==0]['Age'],hist=False)
sns.distplot(df2[df2['Survived']==1]['Age'],hist=False)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
y=pd.crosstab(df2['Pclass'],df2['Survived'])

# %%
sns.heatmap(y)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(df2.groupby('Pclass').mean(numeric_only=True)['Survived']*100)
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(df2.groupby('Sex').mean(numeric_only=True)['Survived']*100)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
(df2.groupby('Embarked').mean(numeric_only=True)['Survived']*100)
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.clustermap(pd.crosstab(df2['Parch'],df2['Survived']))

# %%
df3.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df3,hue='Species')

# %%
new=df4.groupby('year').sum().reset_index()
new
# Out:
#     year                                              month  passengers
# 0   1949  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        1520
# 1   1950  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        1676
# 2   1951  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        2042
# 3   1952  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        2364
# 4   1953  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        2700
# 5   1954  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        2867
# 6   1955  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        3408
# 7   1956  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        3939
# 8   1957  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        4421
# 9   1958  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        4572
# 10  1959  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        5140
# 11  1960  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...        5714

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(df4.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(df4.pivot_table(values='passengers',index='month',columns='year'))
